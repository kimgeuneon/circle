# %% [markdown]
# <a href="https://colab.research.google.com/github/kimgeuneon/circle-root/blob/main/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EA%B0%9C%EC%9A%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 김근언 202004186 인공지능융합공학부
#
# 홍기현 202004128 소프트웨어응용학부
#
#
#
#
# 1, 개요
#
# 2024년 국토·교통 데이터활용 경진대회
#
# 현재 서울시에는 적은 주차장에 비해 불법주차가 너무나 많습니다.
#
# 불법주차로 인해서 생기는 교통사고, 소방차 진입의 어려움, 도로 미관 훼손 등 여러가지 문제가 있습니다.
#
# 따라서, 서울시 불법주차에 관한 데이터와 불법주차가 많은 지역 근처 주차장의 수에 관한 데이터를 분석하여 불법주차가 줄어들 수 있도록 주차장의 수를 개선하고자 합니다.
#
# 2. 데이터 수집.
#
# 서울시 불법주정차 단속 정보 데이터를 받습니다.
#
# 또한, 서울시 주차장 확보율 통계, 서울시 주차방 (구별) 통계, 서울시 주택가 주차장 통계, 서울시 주택인허가대장 주차장 정보 데이터를 받을 예정입니다.
#
#
# 3. 데이터 전처리
#
# 서울시 불법주정차 단속 정보 데이터에서 경도와 위도와 도로명을 제외한 단속일, 단속시간, 구주소에 관한 데이터를 모두 삭제합니다. 도로명 데이터는 시와 구 번지수를 전부 삭제하고 도로명만 남도록 전처리 합니다.
#
# 위 도로명이 같은 지역끼리 데이터를 분류합니다.
#
# 주차장 관련 데이터는 지역별로 어느정도의 주차장이 있는지, 주차장이 얼마나 차있는지 구분할 수 있을 정도로 전처리를 할 것입니다.
#
#
# 4. 데이터 탐색 및 시각화
#
# 도로명 별로 얼마나 좌표가 몰려있는지 기술통계 분석을 통해 요약합니다.
#
# 또한, 몰린 좌표(불법주정차)에 따라 주변 주차장이 얼마나 있는지 데이터 분포를 확인합니다.
#
# 불법 주정차에 따라 주변 주차장의 현황이 어떠한 상관관계로 이루어져있는지 확인합니다.
#
# 불법 주차의 위도 경도를 이용하여 정확한 좌표와 주변 주차장의 규모를 지도와 좌표를 이용해 시각화합니다.
#
#
# 불법주차는 이렇게 많은데, 주차장이 적다면 주차장을 늘린다. 혹은 현황을 유지한다 등 여러가지 결론을 낼 수 있을 것 같습니다.
